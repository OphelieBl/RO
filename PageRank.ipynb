# %%
f = open("alpha15.txt", "r")
L15 = []
for x in f:
    L15.append(float(x))
print(len(L15))
# Out:
# 2070486

# %%
f = open("alpha1.txt", "r")
L1 = []
for x in f:
    L1.append(float(x))
print(len(L1))
# Out:
# 2070486

# %%
6211463-4140977-2070486
# Out:
# 0

# %%
f = open("alpha2.txt", "r")
L2 = []
for x in f:
    L2.append(float(x))
print(len(L2))
# Out:
# 2070486

# %%
f = open("alpha5.txt", "r")
L5 = []
for x in f:
    L5.append(float(x))
print(len(L5))
# Out:
# 2070486

# %%
f = open("alpha9.txt", "r")
L9 = []
for x in f:
    L9.append(float(x))
print(len(L9))
# Out:
# 2070486

# %%
f = open("dout.txt", "r")
Dout = []
for x in f:
    Dout.append(float(x))
print(len(Dout))
# Out:
# 2070486

# %%
f = open("din.txt", "r")
Din = []
for x in f:
    Din.append(float(x))
print(len(Din))
# Out:
# 2070486

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#plt.scatter(L15,L1)
sns.regplot(L15, L1, fit_reg=False, scatter_kws={'s':5})
plt.show()

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(xscale="log", yscale="log")
sns.regplot(L15, L1, ax=ax,fit_reg=False, scatter_kws={'s':5})

# %%
sns.regplot(L15, L2, fit_reg=False)

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(xscale="log", yscale="log")
sns.regplot(L15, L2, fit_reg=False)

# %%
sns.regplot(L15, L5, fit_reg=False)

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(xscale="log", yscale="log")
sns.regplot(L15, L5, fit_reg=False)

# %%
sns.regplot(L15, L9, fit_reg=False)

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(xscale="log", yscale="log")
sns.regplot(L15, L9, fit_reg=False)

# %%
sns.regplot(L15, Dout, fit_reg=False)

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(xscale="log", yscale="log")
sns.regplot(L15, Dout, fit_reg=False)

# %%
sns.regplot(L15, Din, fit_reg=False)

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(xscale="log", yscale="log")
sns.regplot(L15, Din, fit_reg=False)

# %%
import numpy as np
Lsort = np.argsort(L15)

# %%
L15[Lsort[0]]
# Out:
# 0.0

# %%
print(Lsort[-1],
L15[Lsort[-1]])
# Out:
# 837290 0.004591

# %%
maxProba = [3434750, 31717, 11867, 36165, 36164]
minProba = [9626724, 1240694, 4266367, 4266388, 4266416]

# %%
import re
f = open("alr21--pageNum2Name--enwiki-20071018.txt", "r")
Lname = []
for x in f:
    Lname.append(x)

Lother = []
for x in Lname :
    sep = re.split('\s+', x)
    Lother.append(sep[1])
    if (int(sep[0]) in maxProba):
        print('maxProba')
        print(sep[0])
        print(sep)
    if (int(sep[0]) in minProba):
        print('minProba')
        print(sep[0])
        print(sep)
# Out:
# maxProba
# 11867
# ['11867', 'Germany', '']
# maxProba
# 31717
# ['31717', 'United', 'Kingdom', '']
# maxProba
# 36164
# ['36164', '2006', '']
# maxProba
# 36165
# ['36165', '2007', '']
# minProba
# 1240694
# ['1240694', 'Lusik', '']
# maxProba
# 3434750
# ['3434750', 'United', 'States', '']
# minProba
# 4266367
# ['4266367', 'Dipterocarpus', 'humeratus', '']
# minProba
# 4266388
# ['4266388', 'Fantasy', 'name', 'generator', '']
# minProba
# 4266416
# ['4266416', 'Dipterocarpus', 'kerrii', '']
# minProba
# 9626724
# ['9626724', 'List', 'of', 'U.S.', 'Città', 'di', 'Palermo', 'managers', '']

# %%
for i in maxProba : 
    print(Lname[i])
    print(L15[Lname[i]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-d49b9d2e446a> in <module>
#       1 for i in maxProba :
# ----> 2     print(Lname[i])
#       3     print(L15[Lname[i]])
#
# IndexError: list index out of range

# %%
import re
f = open("alr21--pageNum2Name--enwiki-20071018.txt", "r")
Lname = []
for x in f:
    Lname.append(x)

Lother = []
mostVisited=[]
for x in Lname :
    sep = re.split('\s+', x)
    if (int(sep[0]) in maxProba):
        mostVisited.append(sep[0])
    Lother.append(sep[1])
print(mostVisited)
# Out:
# ['17262', '19983']
